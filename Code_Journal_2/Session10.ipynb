# %% [markdown]
# 1. Create a Jupyter notebook, import matplotlib. On the numpy website, read about the random number distributions available for pulling random variates.
# 2. Select your favorite distribution (other than uniform) and pull 1000 random numbers from that distribution.
# 3. Histogram the random numbers into 100 bins, and plot the histogram.
# 4. Label your axes and save the figure as a PDF.
#    #Alexis Valdes
#    #2/9/2024
#    #ASTR19

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
size = 10. # shape
samples = 1000
s = np.random.power(size, samples)

plt.hist(s, bins=100, alpha=0.5, edgecolor="black")

plt.xlabel('X value')
plt.ylabel('# of points')
plt.title("Power Distrubution")
plt.savefig("session10.pdf", dpi=300, bbox_inches="tight", facecolor="white")

plt.show()
